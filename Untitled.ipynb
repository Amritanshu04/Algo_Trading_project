# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
a= [1,2,3,5,7,9]
a
# Out:
# [1, 2, 3, 5, 7, 9]

# %%
import yfinance as yf

tickers = ["RELIANCE.NS", "HDFCBANK.NS", "TCS.NS", "INFY.NS", "HDFC.NS" ,"ITC.NS"]
df = yf.download(tickers, start="2002-02-11", end="2023-02-10")

print(df)
# Out:
# [*********************100%***********************]  6 of 6 completed
#               Adj Close                                                     \
#                 HDFC.NS  HDFCBANK.NS      INFY.NS      ITC.NS  RELIANCE.NS
# Date
# 2002-02-11          NaN    19.542913    40.047707   10.052059    37.901165
# 2002-02-12          NaN    19.726599    40.145008    9.892348    37.974850
# 2002-02-13          NaN    19.641163    40.509068    9.874055    38.073097
# 2002-02-14          NaN    19.508741    40.995033    9.983109    38.263481
# 2002-02-15          NaN    19.952997    41.022839   10.218806    38.760880
# ...                 ...          ...          ...         ...          ...
# 2023-02-03  2694.649902  1658.800049  1599.400024  380.649994  2329.000000
# 2023-02-06  2683.149902  1651.750000  1569.849976  383.399994  2311.449951
# 2023-02-07  2679.199951  1654.199951  1562.400024  373.250000  2305.899902
# ...

# %%
df.head()
# Out:
#            Adj Close                                                       \
#              HDFC.NS HDFCBANK.NS    INFY.NS     ITC.NS RELIANCE.NS TCS.NS
# Date
# 2002-02-11       NaN   19.542913  40.047707  10.052059   37.901165    NaN
# 2002-02-12       NaN   19.726599  40.145008   9.892348   37.974850    NaN
# 2002-02-13       NaN   19.641163  40.509068   9.874055   38.073097    NaN
# 2002-02-14       NaN   19.508741  40.995033   9.983109   38.263481    NaN
# 2002-02-15       NaN   19.952997  41.022839  10.218806   38.760880    NaN
#
#              Close                                    ...       Open  \
#            HDFC.NS HDFCBANK.NS    INFY.NS     ITC.NS  ...    INFY.NS
# Date                                                  ...
# 2002-02-11     NaN   22.875000  58.523438  15.874444  ...  59.375000
# 2002-02-12     NaN   23.090000  58.665627  15.622222  ...  58.921875
# 2002-02-13     NaN   22.990000  59.197655  15.593333  ...  59.218750
# ...

# %%
df.tail()
# Out:
#               Adj Close                                                     \
#                 HDFC.NS  HDFCBANK.NS      INFY.NS      ITC.NS  RELIANCE.NS
# Date
# 2023-02-03  2694.649902  1658.800049  1599.400024  380.649994  2329.000000
# 2023-02-06  2683.149902  1651.750000  1569.849976  383.399994  2311.449951
# 2023-02-07  2679.199951  1654.199951  1562.400024  373.250000  2305.899902
# 2023-02-08  2685.800049  1654.000000  1590.500000  375.549988  2351.949951
# 2023-02-09  2673.250000  1650.550049  1617.000000  374.250000  2356.050049
#
#                                Close                                        \
#                  TCS.NS      HDFC.NS  HDFCBANK.NS      INFY.NS      ITC.NS
# Date
# 2023-02-03  3482.300049  2694.649902  1658.800049  1599.400024  380.649994
# 2023-02-06  3459.949951  2683.149902  1651.750000  1569.849976  383.399994
# 2023-02-07  3472.550049  2679.199951  1654.199951  1562.400024  373.250000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5226 entries, 2002-02-11 to 2023-02-09
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   (Adj Close, HDFC.NS)      5125 non-null   float64
#  1   (Adj Close, HDFCBANK.NS)  5226 non-null   float64
#  2   (Adj Close, INFY.NS)      5226 non-null   float64
#  3   (Adj Close, ITC.NS)       5222 non-null   float64
#  4   (Adj Close, RELIANCE.NS)  5223 non-null   float64
#  5   (Adj Close, TCS.NS)       5094 non-null   float64
#  6   (Close, HDFC.NS)          5125 non-null   float64
#  7   (Close, HDFCBANK.NS)      5226 non-null   float64
#  8   (Close, INFY.NS)          5226 non-null   float64
#  9   (Close, ITC.NS)           5222 non-null   float64
#  10  (Close, RELIANCE.NS)      5223 non-null   float64
#  11  (Close, TCS.NS)           5094 non-null   float64
#  12  (High, HDFC.NS)           5125 non-null   float64
# ...

# %%
df.to_csv("dfstocksdata.csv")

# %%
stocks= pd.read_csv("dfstocksdata.csv")

# %%
stocks
# Out:
#       Unnamed: 0          Adj Close         Adj Close.1         Adj Close.2  \
# 0            NaN            HDFC.NS         HDFCBANK.NS             INFY.NS
# 1           Date                NaN                 NaN                 NaN
# 2     2002-02-11                NaN   19.54291343688965  40.047706604003906
# 3     2002-02-12                NaN  19.726598739624023    40.1450080871582
# 4     2002-02-13                NaN  19.641162872314453   40.50906753540039
# ...          ...                ...                 ...                 ...
# 5223  2023-02-03   2694.64990234375   1658.800048828125  1599.4000244140625
# 5224  2023-02-06   2683.14990234375             1651.75  1569.8499755859375
# 5225  2023-02-07  2679.199951171875   1654.199951171875  1562.4000244140625
# 5226  2023-02-08  2685.800048828125              1654.0              1590.5
# 5227  2023-02-09            2673.25   1650.550048828125              1617.0
#
# ...

# %%
stocks = pd.read_csv("dfstocksdata.csv",header=[0,1])

# %%
stocks
# Out:
#      Unnamed: 0_level_0    Adj Close                                        \
#      Unnamed: 0_level_1      HDFC.NS  HDFCBANK.NS      INFY.NS      ITC.NS
# 0                  Date          NaN          NaN          NaN         NaN
# 1            2002-02-11          NaN    19.542913    40.047707   10.052059
# 2            2002-02-12          NaN    19.726599    40.145008    9.892348
# 3            2002-02-13          NaN    19.641163    40.509068    9.874055
# 4            2002-02-14          NaN    19.508741    40.995033    9.983109
# ...                 ...          ...          ...          ...         ...
# 5222         2023-02-03  2694.649902  1658.800049  1599.400024  380.649994
# 5223         2023-02-06  2683.149902  1651.750000  1569.849976  383.399994
# 5224         2023-02-07  2679.199951  1654.199951  1562.400024  373.250000
# 5225         2023-02-08  2685.800049  1654.000000  1590.500000  375.549988
# ...

# %%
stocks = pd.read_csv("dfstocksdata.csv",header=[0,1],index_col=[0])
stocks
# Out:
#               Adj Close                                                     \
#                 HDFC.NS  HDFCBANK.NS      INFY.NS      ITC.NS  RELIANCE.NS
# Date
# 2002-02-11          NaN    19.542913    40.047707   10.052059    37.901165
# 2002-02-12          NaN    19.726599    40.145008    9.892348    37.974850
# 2002-02-13          NaN    19.641163    40.509068    9.874055    38.073097
# 2002-02-14          NaN    19.508741    40.995033    9.983109    38.263481
# 2002-02-15          NaN    19.952997    41.022839   10.218806    38.760880
# ...                 ...          ...          ...         ...          ...
# 2023-02-03  2694.649902  1658.800049  1599.400024  380.649994  2329.000000
# 2023-02-06  2683.149902  1651.750000  1569.849976  383.399994  2311.449951
# 2023-02-07  2679.199951  1654.199951  1562.400024  373.250000  2305.899902
# 2023-02-08  2685.800049  1654.000000  1590.500000  375.549988  2351.949951
# ...

# %%
stocks = pd.read_csv("dfstocksdata.csv",header=[0,1],index_col=[0], parse_dates=[0])
stocks
# Out:
#               Adj Close                                                     \
#                 HDFC.NS  HDFCBANK.NS      INFY.NS      ITC.NS  RELIANCE.NS
# Date
# 2002-02-11          NaN    19.542913    40.047707   10.052059    37.901165
# 2002-02-12          NaN    19.726599    40.145008    9.892348    37.974850
# 2002-02-13          NaN    19.641163    40.509068    9.874055    38.073097
# 2002-02-14          NaN    19.508741    40.995033    9.983109    38.263481
# 2002-02-15          NaN    19.952997    41.022839   10.218806    38.760880
# ...                 ...          ...          ...         ...          ...
# 2023-02-03  2694.649902  1658.800049  1599.400024  380.649994  2329.000000
# 2023-02-06  2683.149902  1651.750000  1569.849976  383.399994  2311.449951
# 2023-02-07  2679.199951  1654.199951  1562.400024  373.250000  2305.899902
# 2023-02-08  2685.800049  1654.000000  1590.500000  375.549988  2351.949951
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close',     'HDFC.NS'),
#             ('Adj Close', 'HDFCBANK.NS'),
#             ('Adj Close',     'INFY.NS'),
#             ('Adj Close',      'ITC.NS'),
#             ('Adj Close', 'RELIANCE.NS'),
#             ('Adj Close',      'TCS.NS'),
#             (    'Close',     'HDFC.NS'),
#             (    'Close', 'HDFCBANK.NS'),
#             (    'Close',     'INFY.NS'),
#             (    'Close',      'ITC.NS'),
#             (    'Close', 'RELIANCE.NS'),
#             (    'Close',      'TCS.NS'),
#             (     'High',     'HDFC.NS'),
#             (     'High', 'HDFCBANK.NS'),
#             (     'High',     'INFY.NS'),
#             (     'High',      'ITC.NS'),
#             (     'High', 'RELIANCE.NS'),
#             (     'High',      'TCS.NS'),
#             (      'Low',     'HDFC.NS'),
#             (      'Low', 'HDFCBANK.NS'),
#             (      'Low',     'INFY.NS'),
#             (      'Low',      'ITC.NS'),
# ...

# %%
#convert multi index to one tuple
stocks.columns=stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([    ('Adj Close', 'HDFC.NS'), ('Adj Close', 'HDFCBANK.NS'),
#            ('Adj Close', 'INFY.NS'),      ('Adj Close', 'ITC.NS'),
#        ('Adj Close', 'RELIANCE.NS'),      ('Adj Close', 'TCS.NS'),
#                ('Close', 'HDFC.NS'),     ('Close', 'HDFCBANK.NS'),
#                ('Close', 'INFY.NS'),          ('Close', 'ITC.NS'),
#            ('Close', 'RELIANCE.NS'),          ('Close', 'TCS.NS'),
#                 ('High', 'HDFC.NS'),      ('High', 'HDFCBANK.NS'),
#                 ('High', 'INFY.NS'),           ('High', 'ITC.NS'),
#             ('High', 'RELIANCE.NS'),           ('High', 'TCS.NS'),
#                  ('Low', 'HDFC.NS'),       ('Low', 'HDFCBANK.NS'),
#                  ('Low', 'INFY.NS'),            ('Low', 'ITC.NS'),
